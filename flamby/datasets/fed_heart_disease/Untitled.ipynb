# %%
from flamby.datasets.fed_heart_disease import FedHeartDisease, HeartDiseaseRaw

# To load the first center as a pytorch dataset
center0 = FedHeartDisease(center=0, train=True)
# To load the second center as a pytorch dataset
center1 = FedHeartDisease(center=1, train=True)
# To load the second center as a pytorch dataset
center2 = FedHeartDisease(center=2, train=True)
# To load the second center as a pytorch dataset
center3 = FedHeartDisease(center=2, train=True)
# To sample batches from each of the local datasets use the traditional pytorch API
from torch.utils.data import DataLoader as dl

X, y = next(iter(dl(center0, batch_size=8, shuffle=True, num_workers=0)))
print(X)
print(y)

X, y = next(iter(dl(center1, batch_size=8, shuffle=True, num_workers=0)))
print(X)
print(y)

X, y = next(iter(dl(center2, batch_size=8, shuffle=True, num_workers=0)))
print(X)
print(y)

X, y = next(iter(dl(center3, batch_size=8, shuffle=True, num_workers=0)))
print(X)
print(y)
# Out:
# tensor([[ 0.8556, -1.4656,  0.4212,  0.3995, -0.4120,  0.4211, -0.6710,  2.3092,
#          -0.3952, -0.6398,  1.0229, -0.1005,  0.9925],
#         [-1.4409,  0.6789, -1.2641, -0.2788, -0.4120,  0.1040, -0.6710, -0.9518,
#           2.5176, -0.6398, -0.9727, -0.1005, -1.0025],
#         [ 0.6369, -1.4656, -1.7136,  1.4272, -0.4120,  0.4211, -0.6710, -0.9518,
#          -0.3952,  1.5553, -0.9727, -0.1005, -1.0025],
#         [-1.8783,  0.6789, -0.1406,  0.0295, -0.4120,  1.6442, -0.6710,  2.2186,
#          -0.3952,  1.5553, -0.9727, -0.1005, -1.0025],
#         [-0.2379,  0.6789,  1.0953,  1.0161,  2.4151,  1.2365, -0.6710,  0.1352,
#          -0.3952, -0.6398, -0.9727, -0.1005, -1.0025],
#         [ 1.5118,  0.6789, -0.8147,  0.5845, -0.4120,  0.0134, -0.6710, -0.0460,
#          -0.3952,  1.5553, -0.9727, -0.1005, -1.0025],
#         [ 0.5275,  0.6789, -1.2641, -0.1966, -0.4120, -0.3943,  1.4828,  0.1352,
#          -0.3952, -0.6398,  1.0229, -0.1005,  0.9925],
# ...
